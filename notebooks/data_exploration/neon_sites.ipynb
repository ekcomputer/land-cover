# %%
import os
from land_cover.water_quality_data import NEON_AK_WQ_DIR, NEON_AK_CHEM_SURFACE_DIR
from land_cover.plotting import plot_neon_analytes_timeseries_pandas, plot_neon_in_situ_timeseries_pandas
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Lab data

# %% [markdown]
# By site

# %%
plot_neon_analytes_timeseries_pandas(
    os.path.join(NEON_AK_CHEM_SURFACE_DIR, "stackedFiles/swc_externalLabDataByAnalyte.csv"),
    ("DOC", "DIC", "UV Absorbance (280 nm)", "TP", "TN"),
    hue="siteID",
)

# %% [markdown]
# By location

# %%
plot_neon_analytes_timeseries_pandas(
    os.path.join(NEON_AK_CHEM_SURFACE_DIR, "stackedFiles/swc_externalLabDataByAnalyte.csv"),
    ("DOC", "DIC", "UV Absorbance (280 nm)", "TP", "TN"),
    hue="namedLocation",
    site_id_filter="TOOK",
    outlier_iqr=[0.01, 0.99],
)

# %%
plot_neon_analytes_timeseries_pandas(
    os.path.join(NEON_AK_CHEM_SURFACE_DIR, "stackedFiles/swc_externalLabDataByAnalyte.csv"),
    ("DOC", "DIC", "UV Absorbance (280 nm)", "TP", "TN"),
    hue="namedLocation",
    site_id_filter="CARI"
)

# %% [markdown]
# # Water quality monitor data

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=10000,
    date_var="startDateTime",
    y="chlorophyll",
    resample="1D",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=10000,
    date_var="startDateTime",
    y="chlorophyll",
    resample="1D",
)

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=10000,
    date_var="startDateTime",
    y="chlorophyll",
    resample="1D",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2018-01-01 00:00:00+00:00", "2019-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2019-01-01 00:00:00+00:00", "2020-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2020-01-01 00:00:00+00:00", "2021-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2021-01-01 00:00:00+00:00", "2022-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2022-01-01 00:00:00+00:00", "2023-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",

# %%
plot_neon_in_situ_timeseries_pandas(
    os.path.join(NEON_AK_WQ_DIR, "stackedFiles/waq_instantaneous.csv"),
    use_cols=["startDateTime", "siteID", "chlorophyll"],
    decimate=1,
    date_var="startDateTime",
    y="chlorophyll",
    date_filter=["2023-01-01 00:00:00+00:00", "2024-01-01 00:00:00+00:00"],
    resample="12H",
)
# Out:
# /Users/ekyzivat/Library/CloudStorage/Dropbox/Python/ABOVE3_land_cover/land_cover/plotting.py:395: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   kind="line",
