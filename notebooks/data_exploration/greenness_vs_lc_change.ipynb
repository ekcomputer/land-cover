# %% [markdown]
# Did lakes with declining green water color co-occur with woody vegetation expansion? \
# Did lakes with increasing aquatic vegetation co-occur with increasing woody or herbaceous vegetation?
#
# Or was hydrologic change the main driver?

# %% [markdown]
# Run after notebooks/joins/land-cover-buffer-greenness-above-lc2.py

# %% [markdown]
# ```shell
# ekyzivat ABOVE3_land_cover :~$ head -n 1 /Volumes/metis/ABOVE3/land_cover_joins/out/glakes_green_abovelc25/xlsx/greennessx2_albers_landCoverBuffers_core_tsFeatures.csv
# ,Lake_id_glakes,Area_PW_glakes,areaP1,areaP2,areaP3,NDVI8499,NDVI0010,NDVI1121,vegeP1,validP1,vegeP2,validP2,vegeP3,validP3,occP1,occP2,occP3,area_1984_1999_wm,area_2000_2009_wm,area_2010_2019_wm,LEV_p1,LEV_p2,LEV_p3,LEV_p13ain,LEV_p13rin,LEV_p23ain,LEV_p23rin,LEV_p13occ_ain,LEV_p23occ_ain,LEV_p13in,max_bound_dist,mean_bound_dist,Lake_area_hylak,Shore_len_hylak,Shore_dev_hylak,Vol_total_hylak,Depth_avg_hylak,Elevation_hylak,Slope_100_hylak,Wshd_area_hylak,sen_slope,mann_kendall_trend,trend_significance,b2_mean,b2_stddev,hylak_count,Dmax_est_PAVEW_m,Dmax_use_m,dyn_ratio_glak_hylak,depth_ratio_globath,Bare_Sparsely_vegetated_2014,Deciduous_Forest_2014,Evergreen_Forest_2014,Mixed_Forest_2014,Herb_2014,Shrub_2014,Water_2014,Wetland_2014,Sparse_2014,Total_inun_RSD,Total_inun_dyn_pct,Hi_water_yr,Lo_water_yr,Dominant_veg_2014,Dominant_veg_group_2014,Dominant_veg_1986,Dominant_veg_group_1986,SDF,Perim_area_ratio,Total_inun_change,Total_inun_trend
# ekyzivat ABOVE3_land_cover :~$ head -n 1 /Volumes/metis/ABOVE3/land_cover_joins/out/glakes_green_abovelc25/xlsx/greennessx2_albers_landCoverBuffers_short_tsFeatures.csv
# Lake_id_glakes,Area_m2,Perim_m2,Bare_Sparsely_vegetated_2014,Deciduous_Forest_2014,Evergreen_Forest_2014,Mixed_Forest_2014,Herb_2014,Shrub_2014,Water_2014,Wetland_2014,Ice_Snow_2014,Year_2014,Littoral_wetland_pct_2014,Bare_Sparsely_vegetated_pct_2014,Deciduous_Forest_pct_2014,Evergreen_Forest_pct_2014,Mixed_Forest_pct_2014,Herb_pct_2014,Shrub_pct_2014,Ice_Snow_pct_2014,Wetland_pct_2014,Total_inun_2014,Trees_2014,Sparse_2014,Trees_pct_2014,Sparse_pct_2014,Total_inun_pct_2014,Bare_Sparsely_vegetated_med,Deciduous_Forest_med,Evergreen_Forest_med,Mixed_Forest_med,Herb_med,Shrub_med,Water_med,Wetland_med,Ice_Snow_med,Year_med,Littoral_wetland_pct_med,Bare_Sparsely_vegetated_pct_med,Deciduous_Forest_pct_med,Evergreen_Forest_pct_med,Mixed_Forest_pct_med,Herb_pct_med,Shrub_pct_med,Ice_Snow_pct_med,Wetland_pct_med,Total_inun_med,Trees_med,Sparse_med,Trees_pct_med,Sparse_pct_med,Total_inun_pct_med,Total_inun_RSD,Total_inun_dyn_pct,Hi_water_yr,Lo_water_yr,Dominant_veg_1986,Dominant_veg_group_1986,Dominant_veg_2014,Dominant_veg_group_2014,SDF,Perim_area_ratio,Total_inun_change,Total_inun_trend,Trees_change,Trees_trend,Shrub_change,Shrub_trend,Wetland_change,Wetland_trend,Herb_change,Herb_trend,Sparse_change,Sparse_trend,EF_diff,DF_diff,Shrub_diff,F_diff,Water_diff_raw
# ekyzivat ABOVE3_land_cover :~$ head -n 1 /Volumes/metis/ABOVE3/land_cover_joins/out/glakes_green_abovelc25/xlsx/greennessx2_albers_landCoverBuffers_short_tsFeatures.csv
# ekyzivat ABOVE3_land_cover :~$ head -n 1 /Volumes/metis/ABOVE3/land_cover_joins/out/glakes_green_abovelc25/xlsx/greennessx2_albers_landCoverBuffers_core_tsFeatures.csv
# ,Lake_id_glakes,Area_PW_glakes,areaP1,areaP2,areaP3,NDVI8499,NDVI0010,NDVI1121,vegeP1,validP1,vegeP2,validP2,vegeP3,validP3,occP1,occP2,occP3,area_1984_1999_wm,area_2000_2009_wm,area_2010_2019_wm,LEV_p1,LEV_p2,LEV_p3,LEV_p13ain,LEV_p13rin,LEV_p23ain,LEV_p23rin,LEV_p13occ_ain,LEV_p23occ_ain,LEV_p13in,max_bound_dist,mean_bound_dist,Lake_area_hylak,Shore_len_hylak,Shore_dev_hylak,Vol_total_hylak,Depth_avg_hylak,Elevation_hylak,Slope_100_hylak,Wshd_area_hylak,sen_slope,mann_kendall_trend,trend_significance,b2_mean,b2_stddev,hylak_count,Dmax_est_PAVEW_m,Dmax_use_m,dyn_ratio_glak_hylak,depth_ratio_globath,Bare_Sparsely_vegetated_2014,Deciduous_Forest_2014,Evergreen_Forest_2014,Mixed_Forest_2014,Herb_2014,Shrub_2014,Water_2014,Wetland_2014,Sparse_2014,Total_inun_RSD,Total_inun_dyn_pct,Hi_water_yr,Lo_water_yr,Dominant_veg_2014,Dominant_veg_group_2014,Dominant_veg_1986,Dominant_veg_group_1986,SDF,Perim_area_ratio,Total_inun_change,Total_inun_trend,EF_diff,DF_diff,Shrub_diff,F_diff,Water_diff_raw
# ekyzivat ABOVE3_land_cover :~$ head -n 1 /Volumes/metis/ABOVE3/land_cover_joins/out/glakes_green_abovelc25/xlsx/greennessx2_albers_landCoverBuffers_norm.csv
# ,Bare_Sparsely_vegetated,Deciduous_Forest,Evergreen_Forest,Mixed_Forest,Herb,Shrub,Water,Wetland,Ice_Snow,Year,Lake_id_glakes,Area_m2,Perim_m2,Littoral_wetland_pct,Bare_Sparsely_vegetated_pct,Deciduous_Forest_pct,Evergreen_Forest_pct,Mixed_Forest_pct,Herb_pct,Shrub_pct,Ice_Snow_pct,Wetland_pct,Total_inun,Trees,Sparse,Trees_pct,Sparse_pct,Total_inun_pct
# ekyzivat ABOVE3_land_cover :~$
# ```

# %%
import geopandas as gpd
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, PowerNorm
import seaborn as sns
from tqdm import tqdm
import numpy as np
import pandas as pd
import shapely
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io import img_tiles

from land_cover.load import loadGreenness, plot_dir, time_series_features_csv_pth
from land_cover.plotting import reg_hexplot, add_r2, add_regress, plot_choro_and_hist

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_out_norm_pth = time_series_features_csv_pth.replace(
    ".csv", "_norm.csv"
)
csv_out_time_series_features_pth = time_series_features_csv_pth.replace(
    ".csv", "_tsFeatures.csv"
)
csv_out_time_series_features_core_pth = time_series_features_csv_pth.replace(".csv", "_core_tsFeatures.csv")
csv_out_time_series_features_short_pth = time_series_features_csv_pth.replace(".csv", "_short_tsFeatures.csv")

# %%
# df = pd.read_csv(csv_out_time_series_features_core_pth)
df = pd.read_csv(csv_out_time_series_features_pth)
# Out:
# /var/folders/rv/sn0kln2103b9fs4xl56n3w7w0000gn/T/ipykernel_43271/4234328880.py:1: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_out_time_series_features_pth)

# %%
df.info(max_cols=500, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1878284 entries, 0 to 1878283
# Data columns (total 153 columns):
#  #    Column                            Non-Null Count    Dtype
# ---   ------                            --------------    -----
#  0    Unnamed: 0                        1878284 non-null  int64
#  1    Lake_id_glakes                    1878284 non-null  int64
#  2    Area_bound_glakes                 1878284 non-null  float64
#  3    Area_PW_glakes                    1877185 non-null  float64
#  4    Continent_glakes                  1878284 non-null  object
#  5    Lat_glakes                        1878284 non-null  float64
#  6    Lon_glakes                        1878284 non-null  float64
#  7    GFed_flag_glakes                  1878284 non-null  int64
#  8    PFed_flag_glakes                  1878284 non-null  int64
#  9    Endo_flag_glakes                  1878284 non-null  int64
#  10   Rser_flag_glakes                  1878284 non-null  int64
#  11   Shape_Leng_glakes                 1878284 non-null  float64
#  12   Shape_Area_glakes                 1878284 non-null  float64
#  13   areaP1                            542298 non-null   float64
#  14   areaP2                            542944 non-null   float64
#  15   areaP3                            542944 non-null   float64
#  16   NDVI8499                          154598 non-null   float64
#  17   NDVI0010                          154339 non-null   float64
#  18   NDVI1121                          154869 non-null   float64
#  19   vegeP1                            635157 non-null   float64
#  20   validP1                           635110 non-null   float64
#  21   vegeP2                            635157 non-null   float64
#  22   validP2                           635157 non-null   float64
#  23   vegeP3                            635157 non-null   float64
#  24   validP3                           635157 non-null   float64
#  25   occP1                             635157 non-null   float64
#  26   occP2                             635157 non-null   float64
#  27   occP3                             635157 non-null   float64
#  28   area_1984_1999_wm                 1877185 non-null  float64
#  29   area_2000_2009_wm                 1877185 non-null  float64
#  30   area_2010_2019_wm                 1877185 non-null  float64
#  31   LEV_p1                            493270 non-null   float64
#  32   LEV_p2                            495538 non-null   float64
#  33   LEV_p3                            496044 non-null   float64
#  34   LEV_p13ain                        542293 non-null   float64
#  35   LEV_p13rin                        492887 non-null   float64
#  36   LEV_p23ain                        542944 non-null   float64
#  37   LEV_p23rin                        495273 non-null   float64
#  38   LEV_p13occ_ain                    635157 non-null   float64
#  39   LEV_p23occ_ain                    635157 non-null   float64
#  40   LEV_p13in                         540298 non-null   float64
#  41   max_bound_dist                    1878284 non-null  float64
#  42   mean_bound_dist                   1878284 non-null  float64
#  43   Hylak_id                          493064 non-null   float64
#  44   Lake_name_hylak                   1209 non-null     object
#  45   Country_hylak                     493064 non-null   object
#  46   Continent_hylak                   493064 non-null   object
#  47   Poly_src_hylak                    493064 non-null   object
#  48   Lake_type_hylak                   493064 non-null   float64
#  49   Grand_id_hylak                    493064 non-null   float64
#  50   Lake_area_hylak                   493064 non-null   float64
#  51   Shore_len_hylak                   493064 non-null   float64
#  52   Shore_dev_hylak                   493064 non-null   float64
#  53   Vol_total_hylak                   493064 non-null   float64
#  54   Vol_res_hylak                     493064 non-null   float64
#  55   Vol_src_hylak                     493064 non-null   float64
#  56   Depth_avg_hylak                   493064 non-null   float64
#  57   Dis_avg_hylak                     493064 non-null   float64
#  58   Res_time_hylak                    493064 non-null   float64
#  59   Elevation_hylak                   493064 non-null   float64
#  60   Slope_100_hylak                   493064 non-null   float64
#  61   Wshd_area_hylak                   493064 non-null   float64
#  62   Pour_long_hylak                   493064 non-null   float64
#  63   Pour_lat_hylak                    493064 non-null   float64
#  64   sen_slope                         493064 non-null   float64
#  65   mann_kendall_trend                493064 non-null   object
#  66   trend_significance                493064 non-null   float64
#  67   b2_mean                           436532 non-null   float64
#  68   b2_stddev                         493064 non-null   float64
#  69   hylak_count                       1026363 non-null  float64
#  70   Dmax_est_PAVEW_m                  493064 non-null   float64
#  71   Dmax_use_m                        493064 non-null   float64
#  72   dyn_ratio_glak_hylak              493040 non-null   float64
#  73   depth_ratio_globath               493064 non-null   float64
#  74   Area_m2                           904782 non-null   float64
#  75   Perim_m2                          904782 non-null   float64
#  76   Bare_Sparsely_vegetated_2014      904782 non-null   float64
#  77   Deciduous_Forest_2014             904782 non-null   float64
#  78   Evergreen_Forest_2014             904782 non-null   float64
#  79   Mixed_Forest_2014                 904782 non-null   float64
#  80   Herb_2014                         904782 non-null   float64
#  81   Shrub_2014                        904782 non-null   float64
#  82   Water_2014                        904782 non-null   float64
#  83   Wetland_2014                      904782 non-null   float64
#  84   Ice_Snow_2014                     904782 non-null   float64
#  85   Year_2014                         904782 non-null   float64
#  86   Littoral_wetland_pct_2014         902770 non-null   float64
#  87   Bare_Sparsely_vegetated_pct_2014  904782 non-null   float64
#  88   Deciduous_Forest_pct_2014         904782 non-null   float64
#  89   Evergreen_Forest_pct_2014         904782 non-null   float64
#  90   Mixed_Forest_pct_2014             904782 non-null   float64
#  91   Herb_pct_2014                     904782 non-null   float64
#  92   Shrub_pct_2014                    904782 non-null   float64
#  93   Ice_Snow_pct_2014                 904782 non-null   float64
#  94   Wetland_pct_2014                  904782 non-null   float64
#  95   Total_inun_2014                   904782 non-null   float64
#  96   Trees_2014                        904782 non-null   float64
#  97   Sparse_2014                       904782 non-null   float64
#  98   Trees_pct_2014                    904782 non-null   float64
#  99   Sparse_pct_2014                   904782 non-null   float64
#  100  Total_inun_pct_2014               904782 non-null   float64
#  101  Bare_Sparsely_vegetated_med       904782 non-null   float64
#  102  Deciduous_Forest_med              904782 non-null   float64
#  103  Evergreen_Forest_med              904782 non-null   float64
#  104  Mixed_Forest_med                  904782 non-null   float64
#  105  Herb_med                          904782 non-null   float64
#  106  Shrub_med                         904782 non-null   float64
#  107  Water_med                         904782 non-null   float64
#  108  Wetland_med                       904782 non-null   float64
#  109  Ice_Snow_med                      904782 non-null   float64
#  110  Year_med                          904782 non-null   float64
#  111  Littoral_wetland_pct_med          903786 non-null   float64
#  112  Bare_Sparsely_vegetated_pct_med   904782 non-null   float64
#  113  Deciduous_Forest_pct_med          904782 non-null   float64
#  114  Evergreen_Forest_pct_med          904782 non-null   float64
#  115  Mixed_Forest_pct_med              904782 non-null   float64
#  116  Herb_pct_med                      904782 non-null   float64
#  117  Shrub_pct_med                     904782 non-null   float64
#  118  Ice_Snow_pct_med                  904782 non-null   float64
#  119  Wetland_pct_med                   904782 non-null   float64
#  120  Total_inun_med                    904782 non-null   float64
#  121  Trees_med                         904782 non-null   float64
#  122  Sparse_med                        904782 non-null   float64
#  123  Trees_pct_med                     904782 non-null   float64
#  124  Sparse_pct_med                    904782 non-null   float64
#  125  Total_inun_pct_med                904782 non-null   float64
#  126  Total_inun_RSD                    903786 non-null   float64
#  127  Total_inun_dyn_pct                903786 non-null   float64
#  128  Hi_water_yr                       904782 non-null   float64
#  129  Lo_water_yr                       904782 non-null   float64
#  130  Dominant_veg_1986                 904782 non-null   object
#  131  Dominant_veg_group_1986           904782 non-null   object
#  132  Dominant_veg_2014                 904782 non-null   object
#  133  Dominant_veg_group_2014           904782 non-null   object
#  134  SDF                               904782 non-null   float64
#  135  Perim_area_ratio                  904782 non-null   float64
#  136  Total_inun_change                 904782 non-null   float64
#  137  Total_inun_trend                  904782 non-null   object
#  138  Trees_change                      904782 non-null   float64
#  139  Trees_trend                       904782 non-null   object
#  140  Shrub_change                      904782 non-null   float64
#  141  Shrub_trend                       904782 non-null   object
#  142  Wetland_change                    904782 non-null   float64
#  143  Wetland_trend                     904782 non-null   object
#  144  Herb_change                       904782 non-null   float64
#  145  Herb_trend                        904782 non-null   object
#  146  Sparse_change                     904782 non-null   float64
#  147  Sparse_trend                      904782 non-null   object
#  148  EF_diff                           904782 non-null   float64
#  149  DF_diff                           904782 non-null   float64
#  150  Shrub_diff                        904782 non-null   float64
#  151  F_diff                            904782 non-null   float64
#  152  Water_diff_raw                    904782 non-null   float64
# dtypes: float64(131), int64(6), object(16)
# memory usage: 2.1+ GB

# %%
# Compute NDVI change

df["NDVI_p1p2_liu"] = (
    df["NDVI0010"] - df["NDVI8499"]
)
df["NDVI_p1p3_liu"] = (
    df["NDVI1121"] - df["NDVI8499"]
)
df["NDVI_p2p3_liu"] = (
    df["NDVI1121"] - df["NDVI0010"]
)

# %%
def pct_change(old, new, denom="old", multiply=True, zero_replace=np.nan):
    """
    Compute percent (or relative) change between two dataframe columns and add as a new column.

    Parameters
    - col_old: name of "baseline" column (string)
    - col_new: name of "new" column (string)
    - denom: denominator choice for relative change: 'old' (default), 'new', or 'mean'
    - multiply: if True, multiply by 100 to return percent (default True). If False, returns fraction.
    - zero_replace: what to do when denominator == 0. If np.nan (default) leaves result NaN.
                    If 'eps', replaces zeros with a tiny epsilon to avoid inf.
                    Or provide a numeric value to use instead.

    Returns
    - Series added to df at out_col and also returned.
    """

    a = old.astype("float64")
    b = new.astype("float64")

    if denom == "old":
        denom_s = a
    elif denom == "new":
        denom_s = b
    elif denom == "mean":
        denom_s = (a + b) / 2.0
    else:
        raise ValueError("denom must be one of 'old', 'new', 'mean'")

    # handle zeros in denominator
    if zero_replace == "eps":
        denom_s = denom_s.replace(0, np.finfo(float).eps)
    elif np.isfinite(zero_replace) and not np.isnan(zero_replace):
        denom_s = denom_s.replace(0, zero_replace)
    else:
        # leave zeros as-is so division yields inf/NaN which can be inspected/filtered
        pass

    res = (b - a) / denom_s

    if multiply:
        res = res * 100.0

    return res

# Example usage:
# df['NDVI_pct_84_11'] = pct_change(df, 'NDVI8499', 'NDVI1121')

# %%
df["water_pchange_p1p3_glakes"] = pct_change(df.area_1984_1999_wm, df.area_2010_2019_wm)
df["water_pchange_p2p3_glakes"] = pct_change(df.area_2000_2009_wm, df.area_2010_2019_wm)
df["water_pchange_p1p2_glakes"] = pct_change(df.area_1984_1999_wm, df.area_2000_2009_wm)

# %%
# df.Total_inun_change.describe()
df.Total_inun_change.describe()
# Out:
# count    904782.000000
# mean          0.026809
# std           2.384814
# min        -291.293000
# 25%          -0.005000
# 50%           0.000000
# 75%           0.014000
# max        1217.953000
# Name: Total_inun_change, dtype: float64

# %%
# OUtliers
df.sen_slope.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Weird...
len(df.Area_PW_glakes.unique())
# Out:
# 14850

# %% [markdown]
# # Plots

# %%
xvars = [
    "EF_diff",
    "DF_diff",
    "F_diff",
    "Shrub_diff",
    # "Water_diff_raw", # next: use Inun_diff
    "Trees_change",
    # "Total_inun_change", # km2
    "Trees_pct_med",
    "Herb_pct_med",
    "water_pchange_p1p3_glakes",
]

# %%
for xvar in xvars:
    reg_hexplot(df, xvar, "sen_slope", x_robust=True, y_robust=True)

# %%
for xvar in xvars:
    reg_hexplot(df, xvar, "LEV_p13occ_ain", x_robust=True, y_robust=True)

# %%
for xvar in xvars:
    reg_hexplot(df, xvar, "NDVI_p1p3", x_robust=True, y_robust=True)

# %%
for xvar in xvars:
    reg_hexplot(df, xvar, "b2_mean", x_robust=True, y_robust=True)

# %%
for xvar in xvars:
    reg_hexplot(df, xvar, "NDVI_p1p3_liu", x_robust=True, y_robust=True)
